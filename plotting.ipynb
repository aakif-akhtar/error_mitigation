# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



h2_su2 = [-1.793195682,
-1.765476655,
-1.781523447,
-1.799575475,
-1.809038081,
-1.271328322,
-1.786844661,
-1.779083949]
h2_ex_pre = [-1.747748492,
-1.744826753,
-1.717918557,
-1.738725545,
-1.73101252,
-1.733286493,
-1.74878216,
-1.744311739,
-1.746037315,
-1.725757756,
-1.737486628]
h2_noisy = [-1.69818871,
-1.610676947,
-1.643203533,
-1.141726266,
-1.643203533,
-1.643203533,
-1.610676947,
-1.6106769470]
h2_cdr = [-1.789762757,
-1.809550558,
-1.786313821,
-1.158884239,
-1.791524918,
-1.834263084,
-1.748434141,
-1.798125225,
-1.227803796,
-1.806336176,
-1.769771643,
-1.802323709,
-1.778896618,
-1.783582317,
-1.76639983]

h2_pec = [-1.487552107,
-0.587543291,
-1.626084958,
-1.626084958]

# plt.scatter(h2_su2, np.linspace(start=1, stop=8, num = 8), label = "su2, zne")
plt.scatter(h2_ex_pre, np.linspace(start=1, stop=11, num = 11), label = "ext_pre, zne")
plt.scatter(h2_noisy,  np.linspace(start=1, stop=8, num = 8), label = "noisy, ext_pre")
# plt.scatter(h2_cdr, np.linspace(start = 1, stop = 8, num = 15), label = "cdr, su2")
plt.scatter(h2_pec, np.linspace(start = 1, stop = 5, num = 4), label = "pec, ext_pre")

plt.title(label="H2 , bond-distance = 0.75")
plt.legend()
plt.grid(True)
plt.show()

# %%
h2_10 = [-0.96584047,
-0.968223546,
-0.963210955,
-0.961362045,
-0.965286668,
-0.941181069,
-0.891101794,]
h2_noisy_10 = [-0.927159598,
-0.66641567,
-0.66641567,
-0.66641567,
-0.927159598,
-0.927159598,
-0.66641567]
plt.scatter(h2_10, np.linspace(start=1, stop=7, num = 7), label = "zne")
plt.scatter(h2_noisy_10, np.linspace(start=1, stop=7, num = 7), label = "noisy")
plt.title(label='H2, bond distance = 10 A')
plt.legend()
plt.grid(True)
plt.show()

# %%
h3_plus_3 = [-3.012562077,
-3.017548823,
-2.970495145,
-2.95588452,
-3.003407688,
-3.004232146,
-3.035372609,
-2.956164445,
-3.038860935,
-3.053166248]
h3_noisy = [-2.502231131,
-2.902752302,
-2.387515424,
-2.502231131,
-2.902752302,
-2.502231131,
-2.902752302,
-2.502231131,
-2.902752302,
-2.902752302]

h3_lamda_4 = [-2.976271492,
-2.962492551,
-2.964776321,
-2.975206427,
-2.871172918]

h3_lamda_2 = [-2.961910433,
-2.905840956,
-2.959365841,
-2.976550407,
-2.964991088]
exact = [-3.15,-3.15,-3.15,-3.15,-3.15,-3.15,-3.15,-3.15,-3.15 ]

plt.scatter(h3_plus_3, np.linspace(start=1, stop=10, num = 10), label = "lamna = 3, zne")
plt.scatter(h3_noisy, np.linspace(start=1, stop=10, num = 10), label = "noisy")
plt.scatter(h3_lamda_4, np.linspace(start=1, stop=5, num = 5), label = "lamna = 4, zne")
plt.scatter(h3_lamda_2, np.linspace(start=1, stop=5, num = 5), label = "lamna = 2, zne")
# plt.scatter(exact, np.linspace(start=1, stop=10, num= 10 ), label = 'exact')
plt.plot(exact, np.linspace(start = 1, stop = 10, num =9), label = "exact")

plt.title(label='H3+, bond distance = 0.87 A')
plt.legend()
plt.grid(True)
plt.show()

# %%
h2_plus_lamda_3 = [-0.528927081,
-0.528196854,
-0.529381452,
-0.531041496,
-0.530321461,
-0.50509647,
-0.544057098,
-0.527811202,
-0.525722901,
-0.535427685]

h2_plus_noisy = [-0.51776936,
-0.503063211,
-0.51776936,
-0.503063211,
-0.51776936,
-0.503063211,
-0.51776936,
-0.503063211]

h2_plus_lamda_4 = [-0.505868695,
-0.499000583,
-0.529507501,
-0.509410101,
-0.485766113]
h2_plus_lamda_2 = [-0.620656244,
-0.44781767,
-0.533737716,
-0.547433578,
-0.513098105]
exact = [-0.535, -0.535, -0.535, -0.535, -0.535, -0.535, -0.535, -0.535, -0.535, -0.535 ]
plt.scatter(h2_plus_lamda_3, np.linspace(start=1, stop=10, num = 10), label = "lamna =3, zne")
plt.scatter(h2_plus_noisy, np.linspace(start=1, stop=8, num = 8), label = "noisy")
plt.scatter(h2_plus_lamda_4, np.linspace(start=1, stop=5, num = 5), label = "lamna = 4, zne")
plt.scatter(h2_plus_lamda_2, np.linspace(start=1, stop=5, num = 5), label = "lamna = 2, zne")
plt.plot(exact, np.linspace(start=1, stop=10, num = 10), label = 'exact')

plt.title(label='H2+, bond distance = 10 A')
plt.legend()
plt.grid(True)
plt.show()
